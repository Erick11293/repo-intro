# %%
import pandas as pd
import numpy as np

# %%
poblacion = pd.read_excel("../data/external/reporte_estadist.xlsx", dtype = str)

# %%
poblacion.columns = list(poblacion.columns[:-2]) + [2007, 2017]

# %%
poblacion = poblacion.drop([0])

# %%
poblacion[2007] = poblacion[2007].fillna(1000).dropna().apply(int)

# %%
poblacion[2017] = poblacion[2017].dropna().apply(int)

# %%
Poblacionperregion = (poblacion
                      .groupby(['Departamento','Provincia'])
                      .apply(lambda y: pd.Series(
                          {2007: y[2007].sum(), 
                           2017: y[2017].sum(), 
                           'Ubigeo': y['Ubigeo'].iloc[0][0:4]
                          }
                      )
                            )
                     )

# %%
poblacion
# Out:
#       Ubigeo Departamento   Provincia    Distrito          Indicador  \
# 1     010202     AMAZONAS       BAGUA    ARAMANGO  Población censada
# 2     010201     AMAZONAS       BAGUA       BAGUA  Población censada
# 3     010203     AMAZONAS       BAGUA    COPALLIN  Población censada
# 4     010204     AMAZONAS       BAGUA    EL PARCO  Población censada
# 5     010205     AMAZONAS       BAGUA       IMAZA  Población censada
# ...      ...          ...         ...         ...                ...
# 1870  250303      UCAYALI  PADRE ABAD    CURIMANA  Población censada
# 1871  250302      UCAYALI  PADRE ABAD     IRAZOLA  Población censada
# 1872  250304      UCAYALI  PADRE ABAD     NESHUYA  Población censada
# 1873  250301      UCAYALI  PADRE ABAD  PADRE ABAD  Población censada
# 1874  250401      UCAYALI       PURUS       PURUS  Población censada
#
#      Unidad de medida   2007   2017
# 1            Personas  11442   9765
# 2            Personas   1000  27102
# 3            Personas   6126   4595
# 4            Personas   1274   1216
# 5            Personas  21409  25162
# ...               ...    ...    ...
# 1870         Personas   6047   7722
# 1871         Personas  18910  10214
# 1872         Personas   1000   7594
# 1873         Personas  25633  29440
# 1874         Personas   3746   2860
#
# [1874 rows x 8 columns]

# %%
g_rate = (Poblacionperregion[2017]/(Poblacionperregion[2007]))**(1/10)

for year in range(2008, 2022):
    Poblacionperregion[year] = Poblacionperregion[year-1]* g_rate

# %%
Poblacionperregion.to_pickle("../data/raw/poblacion-provincia-periodo.pickle")
