# %% [markdown]
# ### Creando un indicador de gasto per capita por provincia

# %% [markdown]
# ##### Librerias

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# ###### Poblacion

# %%
#Se lee la base de poblacion por distrito
population = pd.read_pickle("../../data/raw/poblacion-provincia-periodo.pickle")

# %%
#
population['ubigeo'] = (population['Ubigeo'] # La variable ubigeo
                        .replace({'0701':'1501'}) # Se asigna la provincia del Callao a Lima Matropolitana
                        .apply(str) # Se asigna como string
                       )

# %%
populationpp = (population
                .drop(columns = ['Ubigeo']) #Se elimina la variable Ubigeo
                .groupby("ubigeo") # Se agrupa por la variable ubigeo
                .sum() #Se calcula el agregado
                .sort_index(axis = 1) #Se ordenan las columnas
               )

# %%
populationpp
# Out:
#           2007           2008           2009           2010           2011  \
# ubigeo
# 0101     49700   50252.161055   50810.456554   51374.954649   51945.724251
# 0102     72757   72890.197317   73023.638481   73157.323938   73291.254134
# 0103     27465   27276.482449   27089.258867   26903.320373   26718.658145
# 0104     43311   43226.155971   43141.478147   43056.966202   42972.619812
# 0105     48328   47923.931227   47523.240858   47125.900649   46731.882588
# ...        ...            ...            ...            ...            ...
# 2403     41054   41773.518103   42505.646581   43250.606444   44008.622576
# 2501    333890  338606.421158  343389.464942  348240.072441  353159.198038
# 2502     43933   44444.456868   44961.867988   45485.302677   46014.831060
# 2503     52590   53297.318459   54014.150122   54740.622939   55476.866580
# 2504      3746    3646.259713    3549.175093    3454.675429    3362.691895
#
#                  2012           2013           2014           2015  \
# ubigeo
# 0101     52522.835034   53106.357449   53696.362728   54292.922896
# 0102     73425.429519   73559.850540   73694.517648   73829.431293
# 0103     26535.263424   26353.127510   26172.241762   25992.597600
# 0104     42888.438652   42804.422399   42720.570729   42636.883320
# 0105     46341.158898   45953.702036   45569.484687   45188.479767
# ...               ...            ...            ...            ...
# 2403     44779.923805   45564.742966   46363.316977   47175.886907
# 2501    358147.809598  363206.888657  368337.430615  373540.444934
# 2502     46550.524079   47092.453500   47640.691926   48195.312806
# 2503     56223.012459   56979.193759   57745.545452   58522.204327
# 2504      3273.157497    3186.007025    3101.177005    3018.605654
#
#                  2016      2017           2018           2019           2020  \
# ubigeo
# 0101     54896.110775   55506.0   56122.665021   56746.181117   57376.624402
# 0102     73964.591926   74100.0   74235.655967   74371.560282   74507.713399
# 0103     25814.186500   25637.0   25461.029694   25286.267234   25112.704329
# 0104     42553.359851   42470.0   42386.803447   42303.769871   42220.898954
# 0105     44810.660416   44436.0   44064.472107   43696.050546   43330.709345
# ...               ...       ...            ...            ...            ...
# 2403     48002.698050   48844.0   49700.046725   50571.096643   51457.412704
# 2501    378816.955335  384168.0  389594.631775  395097.918380  400678.942614
# 2502     48756.390441   49324.0   49898.217526   50479.119947   51066.785087
# 2503     59309.309012   60107.0   60915.419673   61734.712329   62565.024206
# 2504      2938.232831    2860.0    2783.850182    2709.727914    2637.579211
#
#                  2021
# ubigeo
# 0101     58014.071836
# 0102     74644.115774
# 0103     24940.332746
# 0104     42138.190377
# 2019    230189.390115  510021.478570
# 2020    232908.103526  516948.331119
# 2021    235664.623822  523973.949287
#
# [15 rows x 219 columns]

# %% [markdown]
# ###### Creando gasto per capita (a nivel de provincia y region)

# %%
#Se lee la base de poblacion por distrito
spending = pd.read_pickle("../../data/raw/gastos-categorias-periodos.pickle")

# %%
# Se reemplaza Callao por Lima
spending['ubigeo'] = spending['ubigeo'].replace({'0701':'1501'})

# %%
# Solo gastos post 2006
spending = spending[spending.year > 2006]

# %%
data = (spending
        .groupby(['ubigeo','year','BtnTipoGobierno','TIPO_G']) #Agrupacion
        [['Devengado','PIM']] #Variables de devengado y PIM
        .sum() # Suma
        .rename(columns = lambda col: "USE_" + col) #Renombrando variables
        .join(populationb.rename("pop")) #Uniendo con la poblacion
        .apply(lambda y: y/y['pop'], axis = 1) #Diviendo las variables por la poblacion
        .drop(columns = ['pop']) #Eliminando poblacion
       )

# %%
data
# Out:
#                                              USE_Devengado     USE_PIM
# ubigeo year BtnTipoGobierno TIPO_G
# 0100   2007 E               GASTO CORRIENTE     306.732225  318.449624
#                             INVERSION           594.520653  671.384116
#                             OTROS                 0.000000    0.013098
#             R               GASTO CORRIENTE     495.237481  502.860138
#                             INVERSION           251.242170  307.413703
# ...                                                    ...         ...
# 9800   2021 E               INVERSION                  NaN         NaN
#                             OTROS                      NaN         NaN
#        2022 E               GASTO CORRIENTE            NaN         NaN
#                             INVERSION                  NaN         NaN
#                             OTROS                      NaN         NaN
#
# [11673 rows x 2 columns]

# %%
data.describe()
# Out:
#        USE_Devengado       USE_PIM
# count   10801.000000  10801.000000
# mean      451.547884    645.063096
# std       753.502420   1574.254447
# min         0.000000      0.000000
# 25%        27.587540     34.396014
# 50%       276.476328    358.983862
# 75%       592.241750    791.754837
# max     24005.008229  70706.284544

# %%
data.index.get_level_values('ubigeo').value_counts()
# Out:
# ubigeo
# 1000    95
# 1400    95
# 1600    95
# 2400    94
# 1100    94
#         ..
# 1702    44
# 2504    44
# 0202    43
# 1608    27
# 2506     4
# Name: count, Length: 222, dtype: int64

# %% [markdown]
# ##### Asignando gasto de region a nivel de provincia

# %%
# Separando regiones de provincias

dataprovince = data.loc[data.index.get_level_values(0).str[2:] != '00']
dataregion = data.loc[data.index.get_level_values(0).str[2:] == '00']

# %%
# Creando variable region

dataprovince.loc[:,'region'] = dataprovince.index.get_level_values(0).str[:2]
dataregion.loc[:,'region'] = dataregion.index.get_level_values(0).str[:2]
# Out:
# /tmp/ipykernel_4225/2166074236.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataprovince.loc[:,'region'] = dataprovince.index.get_level_values(0).str[:2]
# /tmp/ipykernel_4225/2166074236.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataregion.loc[:,'region'] = dataregion.index.get_level_values(0).str[:2]

# %%
dataregion
# Out:
#                                              USE_Devengado     USE_PIM region
# ubigeo year BtnTipoGobierno TIPO_G
# 0100   2007 E               GASTO CORRIENTE     306.732225  318.449624     01
#                             INVERSION           594.520653  671.384116     01
#                             OTROS                 0.000000    0.013098     01
#             R               GASTO CORRIENTE     495.237481  502.860138     01
#                             INVERSION           251.242170  307.413703     01
# ...                                                    ...         ...    ...
# 9800   2021 E               INVERSION                  NaN         NaN     98
#                             OTROS                      NaN         NaN     98
#        2022 E               GASTO CORRIENTE            NaN         NaN     98
#                             INVERSION                  NaN         NaN     98
#                             OTROS                      NaN         NaN     98
#
# [2383 rows x 3 columns]

# %%
dataprovince
# Out:
#                                              USE_Devengado     USE_PIM region
# ubigeo year BtnTipoGobierno TIPO_G
# 0101   2007 M               GASTO CORRIENTE      86.948367   97.448310     01
#                             INVERSION            44.299039  117.808793     01
#                             OTROS                 5.117671    5.372575     01
#        2008 M               GASTO CORRIENTE     161.256832  178.882397     01
#                             INVERSION           368.191322  522.921511     01
# ...                                                    ...         ...    ...
# 2504   2022 M               OTROS                      NaN         NaN     25
# 2506   2015 M               INVERSION                  NaN         NaN     25
#        2016 M               INVERSION                  NaN         NaN     25
#        2017 M               INVERSION                  NaN         NaN     25
#        2018 M               INVERSION                  NaN         NaN     25
#
# [9290 rows x 3 columns]

# %%
# Reordenando variables

dataprovince = (dataprovince
                .set_index('region',append= True) #Creando un nuevo indice
                .stack() #Columnas a indice (equivalente al reshape)
                .unstack([2,3,5]) # Indice a columnas
               )

dataregion = (dataregion
              .set_index('region',append= True)  #Creando un nuevo indice
              .stack() #Columnas a indice (equivalente al reshape)
              .unstack([2,3,5]) #Indice a columnas
              .reset_index('ubigeo', drop = True) #Quitando un indice
             )

# %%
data = dataprovince.join(dataregion)

data = data.sort_index(axis = 1).fillna(0)

# %%
data['period'] = pd.cut(data.index.get_level_values('year'), [2007, 2012, 2017, 2022], include_lowest=False)

# %%
data_agregada = data.groupby(['ubigeo','period']).mean()
# Out:
# /tmp/ipykernel_4225/1265044939.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data_agregada = data.groupby(['ubigeo','period']).mean()

# %%
data_agregada
# Out:
# BtnTipoGobierno                   E                                         \
# TIPO_G              GASTO CORRIENTE                  INVERSION
#                       USE_Devengado      USE_PIM USE_Devengado     USE_PIM
# ubigeo period
# 0101   (2007, 2012]      613.486683   663.863465    841.514225  913.057015
#        (2012, 2017]     1015.540310  1040.358154    857.764669  941.730305
#        (2017, 2022]     1287.842249  1348.714354    856.386871  990.105922
# 0102   (2007, 2012]      613.486683   663.863465    841.514225  913.057015
#        (2012, 2017]     1015.540310  1040.358154    857.764669  941.730305
# ...                             ...          ...           ...         ...
# 2503   (2012, 2017]      727.861718   761.901054    531.659339  598.754745
#        (2017, 2022]      870.713705   915.463171    194.289700  248.665839
# 2504   (2007, 2012]      338.780059   369.023666    312.674108  359.126692
#        (2012, 2017]      727.861718   761.901054    531.659339  598.754745
#        (2017, 2022]      870.713705   915.463171    194.289700  248.665839
#
# BtnTipoGobierno                                             M               \
# TIPO_G                      OTROS             GASTO CORRIENTE
#                     USE_Devengado     USE_PIM   USE_Devengado      USE_PIM
# ubigeo period
# 0101   (2007, 2012]     80.828797   97.273765      195.214402   235.111114
#        (2012, 2017]    372.321931  378.211642      315.033677   384.153054
#        (2017, 2022]    744.009369  756.231622      540.295126   665.987307
# 0102   (2007, 2012]     80.828797   97.273765      157.209036   197.546462
#        (2012, 2017]    372.321931  378.211642      258.239705   297.256747
# ...                           ...         ...             ...          ...
# 2503   (2012, 2017]    133.186281  137.262065      510.529026   591.147347
#        (2017, 2022]    371.826944  378.695264      654.576809   792.148623
# 2504   (2007, 2012]     38.169926   41.559950      798.550757   853.507220
#        (2012, 2017]    133.186281  137.262065     1083.982000  1172.052583
#        (2017, 2022]    371.826944  378.695264     1245.203205  1349.370327
#
# BtnTipoGobierno                                                          \
# TIPO_G                  INVERSION                      OTROS
#                     USE_Devengado      USE_PIM USE_Devengado    USE_PIM
# ubigeo period
# 0101   (2007, 2012]    419.361275   601.802765     21.167243  24.141893
#        (2012, 2017]    829.445214  1206.677703      9.096672   9.699908
#        (2017, 2022]    694.890226  1009.678371      7.729453   9.646190
# 0102   (2007, 2012]    179.329278   239.162895     24.493439  31.249310
#        (2012, 2017]    257.394973   390.089518     16.020187  18.409333
# ...                           ...          ...           ...        ...
# 2503   (2012, 2017]    765.958989  1046.749427     25.907021  33.351478
#        (2017, 2022]    668.294769  1222.751609     41.478932  43.720382
# 2504   (2007, 2012]   1501.485328  1864.645621      8.855951   9.275553
#        (2012, 2017]   1831.601753  2392.072575     48.476438  87.949005
#        (2017, 2022]   1760.384823  2523.061066      4.343825  14.044762
#
# BtnTipoGobierno                   R                                         \
# TIPO_G              GASTO CORRIENTE                  INVERSION
#                       USE_Devengado      USE_PIM USE_Devengado     USE_PIM
# ubigeo period
# 0101   (2007, 2012]      628.823490   653.353086    378.378069  536.595328
#        (2012, 2017]     1185.655711  1216.120941    592.046183  731.499575
#        (2017, 2022]     1905.411895  1963.911630    693.564968  957.440600
# 0102   (2007, 2012]      628.823490   653.353086    378.378069  536.595328
#        (2012, 2017]     1185.655711  1216.120941    592.046183  731.499575
# ...                             ...          ...           ...         ...
# 2503   (2012, 2017]      927.337430   954.087616    435.667272  548.283868
#        (2017, 2022]     1397.327611  1427.376703    634.569648  810.650336
# 2504   (2007, 2012]      599.790252   625.676434    270.378561  446.674682
#        (2012, 2017]      927.337430   954.087616    435.667272  548.283868
#        (2017, 2022]     1397.327611  1427.376703    634.569648  810.650336
#
# BtnTipoGobierno
# TIPO_G                      OTROS
#                     USE_Devengado    USE_PIM
# ubigeo period
# 0101   (2007, 2012]     19.751451  20.538590
#        (2012, 2017]     17.308828  17.602377
#        (2017, 2022]     86.493687  86.826204
# 0102   (2007, 2012]     19.751451  20.538590
#        (2012, 2017]     17.308828  17.602377
# ...                           ...        ...
# 2503   (2012, 2017]     15.233436  15.875008
#        (2017, 2022]     42.326568  44.246396
# 2504   (2007, 2012]     14.159152  20.389682
#        (2012, 2017]     15.233436  15.875008
#        (2017, 2022]     42.326568  44.246396
#
# [585 rows x 18 columns]

# %%
data_agregada.to_pickle("../../data/interim/data_spending.pickle")
